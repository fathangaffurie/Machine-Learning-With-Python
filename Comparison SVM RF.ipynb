# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from jupyterthemes import jtplot
jtplot.style(theme='onedork')

train = pd.read_csv("heart.csv")
train.dropna()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# 12    49    1   1       130   266    0        1      171      0      0.6
# 13    64    1   3       110   211    0        0      144      1      1.8
# 14    58    0   3       150   283    1        0      162      0      1.0
# 15    50    0   2       120   219    0        1      158      0      1.6
# 16    58    0   2       120   340    0        1      172      0      0.0
# 17    66    0   3       150   226    0        1      114      0      2.6
# 18    43    1   0       150   247    0        1      171      0      1.5
# 19    69    0   3       140   239    0        1      151      0      1.8
# 20    59    1   0       135   234    0        1      161      0      0.5
# 21    44    1   2       130   233    0        1      179      1      0.4
# 22    42    1   0       140   226    0        1      178      0      0.0
# 23    61    1   2       150   243    1        1      137      1      1.0
# 24    40    1   3       140   199    0        1      178      1      1.4
# 25    71    0   1       160   302    0        1      162      0      0.4
# 26    59    1   2       150   212    1        1      157      0      1.6
# 27    51    1   2       110   175    0        1      123      0      0.6
# 28    65    0   2       140   417    1        0      157      0      0.8
# 29    53    1   2       130   197    1        0      152      0      1.2
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 273   58    1   0       100   234    0        1      156      0      0.1
# 274   47    1   0       110   275    0        0      118      1      1.0
# 275   52    1   0       125   212    0        1      168      0      1.0
# 276   58    1   0       146   218    0        1      105      0      2.0
# 277   57    1   1       124   261    0        1      141      0      0.3
# 278   58    0   1       136   319    1        0      152      0      0.0
# 279   61    1   0       138   166    0        0      125      1      3.6
# 280   42    1   0       136   315    0        1      125      1      1.8
# 281   52    1   0       128   204    1        1      156      1      1.0
# 282   59    1   2       126   218    1        1      134      0      2.2
# 283   40    1   0       152   223    0        1      181      0      0.0
# 284   61    1   0       140   207    0        0      138      1      1.9
# 285   46    1   0       140   311    0        1      120      1      1.8
# 286   59    1   3       134   204    0        1      162      0      0.8
# 287   57    1   1       154   232    0        0      164      0      0.0
# 288   57    1   0       110   335    0        1      143      1      3.0
# 289   55    0   0       128   205    0        2      130      1      2.0
# 290   61    1   0       148   203    0        1      161      0      0.0
# 291   58    1   0       114   318    0        2      140      0      4.4
# 292   58    0   0       170   225    1        0      146      1      2.8
# 293   67    1   2       152   212    0        0      150      0      0.8
# 294   44    1   0       120   169    0        1      144      1      2.8
# 295   63    1   0       140   187    0        0      144      1      4.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# 7        2   0     3       1
# 8        2   0     3       1
# 9        2   0     2       1
# 10       2   0     2       1
# 11       2   0     2       1
# 12       2   0     2       1
# 13       1   0     2       1
# 14       2   0     2       1
# 15       1   0     2       1
# 16       2   0     2       1
# 17       0   0     2       1
# 18       2   0     2       1
# 19       2   2     2       1
# 20       1   0     3       1
# 21       2   0     2       1
# 22       2   0     2       1
# 23       1   0     2       1
# 24       2   0     3       1
# 25       2   2     2       1
# 26       2   0     2       1
# 27       2   0     2       1
# 28       2   1     2       1
# 29       0   0     2       1
# ..     ...  ..   ...     ...
# 273      2   1     3       0
# 274      1   1     2       0
# 275      2   2     3       0
# 276      1   1     3       0
# 277      2   0     3       0
# 278      2   2     2       0
# 279      1   1     2       0
# 280      1   0     1       0
# 281      1   0     0       0
# 282      1   1     1       0
# 283      2   0     3       0
# 284      2   1     3       0
# 285      1   2     3       0
# 286      2   2     2       0
# 287      2   1     2       0
# 288      1   1     3       0
# 289      1   1     3       0
# 290      2   1     3       0
# 291      0   3     1       0
# 292      1   2     1       0
# 293      1   0     3       0
# 294      0   0     1       0
# 295      2   2     3       0
# 296      1   0     2       0
# 297      1   2     1       0
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
corr = train.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col0 {
#             background-color:  #023858;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col1 {
#             background-color:  #e8e4f0;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col2 {
#             background-color:  #d4d4e8;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col3 {
#             background-color:  #a8bedc;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col4 {
#             background-color:  #b1c2de;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col5 {
#             background-color:  #dedcec;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col6 {
#             background-color:  #fbf3f9;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col7 {
#             background-color:  #fff7fb;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col8 {
#             background-color:  #a7bddb;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col9 {
#             background-color:  #75a9cf;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col10 {
#             background-color:  #cdd0e5;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col11 {
#             background-color:  #7dacd1;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col12 {
#             background-color:  #bdc8e1;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row0_col13 {
#             background-color:  #e7e3f0;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col0 {
#             background-color:  #d9d8ea;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col1 {
#             background-color:  #023858;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col2 {
#             background-color:  #d1d2e6;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col3 {
#             background-color:  #f4edf6;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col4 {
#             background-color:  #fff7fb;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col5 {
#             background-color:  #ede8f3;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col6 {
#             background-color:  #f3edf5;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col7 {
#             background-color:  #d0d1e6;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col8 {
#             background-color:  #9ab8d8;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col9 {
#             background-color:  #91b5d6;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col10 {
#             background-color:  #b0c2de;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col11 {
#             background-color:  #a9bfdc;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col12 {
#             background-color:  #97b7d7;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row1_col13 {
#             background-color:  #efe9f3;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col0 {
#             background-color:  #d3d4e7;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col1 {
#             background-color:  #e0dded;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col2 {
#             background-color:  #023858;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col3 {
#             background-color:  #e2dfee;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col4 {
#             background-color:  #f0eaf4;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col5 {
#             background-color:  #e3e0ee;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col6 {
#             background-color:  #e2dfee;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col7 {
#             background-color:  #75a9cf;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col8 {
#             background-color:  #fbf3f9;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col9 {
#             background-color:  #c9cee4;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col10 {
#             background-color:  #8bb2d4;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col11 {
#             background-color:  #e7e3f0;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col12 {
#             background-color:  #eae6f1;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row2_col13 {
#             background-color:  #3f93c2;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col0 {
#             background-color:  #79abd0;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col1 {
#             background-color:  #e1dfed;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col2 {
#             background-color:  #b9c6e0;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col3 {
#             background-color:  #023858;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col4 {
#             background-color:  #cacee5;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col5 {
#             background-color:  #d2d3e7;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col6 {
#             background-color:  #faf3f9;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col7 {
#             background-color:  #d0d1e6;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col8 {
#             background-color:  #afc1dd;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col9 {
#             background-color:  #78abd0;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col10 {
#             background-color:  #c2cbe2;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col11 {
#             background-color:  #adc1dd;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col12 {
#             background-color:  #bfc9e1;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row3_col13 {
#             background-color:  #dbdaeb;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col0 {
#             background-color:  #8cb3d5;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col1 {
#             background-color:  #f5eff6;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col2 {
#             background-color:  #d5d5e8;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col3 {
#             background-color:  #d4d4e8;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col4 {
#             background-color:  #023858;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col5 {
#             background-color:  #f1ebf5;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col6 {
#             background-color:  #fff7fb;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col7 {
#             background-color:  #c6cce3;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col8 {
#             background-color:  #afc1dd;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col9 {
#             background-color:  #9cb9d9;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col10 {
#             background-color:  #a9bfdc;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col11 {
#             background-color:  #b4c4df;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col12 {
#             background-color:  #b5c4df;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row4_col13 {
#             background-color:  #d2d2e7;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row5_col0 {
#             background-color:  #a7bddb;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row5_col1 {
#             background-color:  #ced0e6;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row5_col2 {
#             background-color:  #afc1dd;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row5_col3 {
#             background-color:  #c5cce3;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row5_col4 {
#             background-color:  #e0deed;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row5_col5 {
#             background-color:  #023858;
#         }    #T_2c3c3648_480b_11e9_85ec_206a8a964735row5_co

# %%
#################### SVM LINEAR

from sklearn import svm
from sklearn.model_selection import train_test_split
  
train1 = train.copy()
  
feature_df = train1[["age","sex","cp","trestbps","thalach","chol","restecg","exang","oldpeak","slope","ca","thal"]]
x = np.asarray(feature_df)
y = np.asarray(train["target"].astype('int'))
  
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state = 5)
  
clf = svm.SVC(kernel='linear')
clf.fit(x_train,y_train)
yhat = clf.predict(x_test)
from sklearn.metrics import jaccard_similarity_score
print(jaccard_similarity_score(y_test,yhat))
# Out:
# 0.9120879120879121

# %%
############     using random forest model

# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()  
x_train = sc.fit_transform(x_train)  
x_test = sc.transform(x_test) 
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=20, random_state=7)  
regressor.fit(x_train, y_train)  
y_pred = regressor.predict(x_test)

for i in range(len(y_pred)):
  if y_pred[i]>=0.5:
    y_pred[i]=1
  else:
    y_pred[i]=0
#print(y_pred)


#prediction_int = y_pred[:,1] >= 0.3 # if prediction is greater than or equal to 0.3 than 1 else 0
#prediction_int = prediction_int.astype(np.int)


from sklearn.metrics import jaccard_similarity_score
print(jaccard_similarity_score(y_test,y_pred))
# Out:
# 0.9120879120879121
